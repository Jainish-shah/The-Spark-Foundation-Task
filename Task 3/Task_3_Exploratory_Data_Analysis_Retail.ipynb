# %% [markdown]
# ## Author: Jainish Shah
# ### Task 3: Exploratory Data Analysis - Retail
# ### GRIP @ The Spark Foundation
#
# AIM : Perform ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’
# As a business manager, try to find out the weak areas where you can
# work to make more profit.

# %%
### Step 0 - Importing the Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
### Step1 - importing the dataset
data = pd.read_csv("SampleSuperstore.csv")

# %%
# testting the loaded dataset
data.head()
# Out:
#         Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0    Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1    Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2    Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3  Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4  Standard Class   Consumer  United States  ...        2     0.20    2.5164
#
# [5 rows x 13 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
data.shape
# Out:
# (9994, 13)

# %%
data['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
data['City'].nunique()
# Out:
# 531

# %%
data['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %% [markdown]
# #### Category and Sub Category with most sell

# %%
data['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
data['Sub-Category'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         Bookcases
# 1            Chairs
# 2            Labels
# 3            Tables
# 4           Storage
#            ...
# 9989    Furnishings
# 9990    Furnishings
# 9991         Phones
# 9992          Paper
# 9993     Appliances
# Name: Sub-Category, Length: 9994, dtype: object>

# %% [markdown]
# #### Visualization of Categories

# %%
plt.hist(data['Category'])
plt.show()

# %%
import plotly.express as px
fig = px.scatter(data, x="Sub-Category", color="Sub-Category")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cd8d9113-2940-4422-932b-7fdb3af1ae43" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cd8d9113-2940-4422-932b-7fdb3af1ae43")) {
#                     Plotly.newPlot(
#                         'cd8d9113-2940-4422-932b-7fdb3af1ae43',
# ...

# %%
plt.pie(data['Category'].value_counts(), labels=data["Category"].value_counts().index,autopct='%1.1f%%')
plt.show()

# %%
fig = px.scatter(data, x="Category", color="Category")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a69d6330-acfb-40ae-afab-874d74b8b7f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a69d6330-acfb-40ae-afab-874d74b8b7f3")) {
#                     Plotly.newPlot(
#                         'a69d6330-acfb-40ae-afab-874d74b8b7f3',
# ...

# %%
# Visualizing by profits

plt.title("Region wise profits")
plt.pie(data['Region'].value_counts(), labels=data['Region'].value_counts().index,autopct='%1.1f%%')
plt.show()

# %%
# High Profit and loss - here we are defining the data into another smaller dataset

hpl =data[data['Profit'] > 3000]
hpl
# Out:
#            Ship Mode      Segment        Country  ... Quantity Discount     Profit
# 509   Standard Class     Consumer  United States  ...        5      0.0  3177.4750
# 2623     First Class  Home Office  United States  ...        4      0.2  3919.9888
# 4098  Standard Class     Consumer  United States  ...        5      0.0  4630.4755
# 4190  Standard Class     Consumer  United States  ...        3      0.0  5039.9856
# 6826  Standard Class    Corporate  United States  ...        5      0.0  8399.9760
# 8153     First Class     Consumer  United States  ...        4      0.0  6719.9808
# 9039  Standard Class     Consumer  United States  ...       13      0.0  4946.3700
#
# [7 rows x 13 columns]

# %%
lossprofit = data[data['Profit']<0]
lossprofit
# Out:
#            Ship Mode      Segment        Country  ... Quantity Discount     Profit
# 3     Standard Class     Consumer  United States  ...        5     0.45  -383.0310
# 14    Standard Class  Home Office  United States  ...        5     0.80  -123.8580
# 15    Standard Class  Home Office  United States  ...        3     0.80    -3.8160
# 23      Second Class     Consumer  United States  ...        2     0.30    -1.0196
# 27    Standard Class     Consumer  United States  ...        7     0.50 -1665.0522
# ...              ...          ...            ...  ...      ...      ...        ...
# 9920  Standard Class    Corporate  United States  ...        7     0.80   -35.8176
# 9921  Standard Class  Home Office  United States  ...        3     0.70    -4.5936
# 9931  Standard Class     Consumer  United States  ...        4     0.15   -40.1960
# 9937    Second Class    Corporate  United States  ...        2     0.20    -1.7772
# ...

# %%
import plotly.express as px
df = px.data.iris()
fig = px.scatter(hpl, x="Profit", y="City", color="City",
                 size='Profit', hover_data=['Profit'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9e8aa1e2-3c0e-4c15-a86e-32e82eddb5bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9e8aa1e2-3c0e-4c15-a86e-32e82eddb5bf")) {
#                     Plotly.newPlot(
#                         '9e8aa1e2-3c0e-4c15-a86e-32e82eddb5bf',
# ...

# %% [markdown]
# ### As a business manager we need to work on places where the loss is high
